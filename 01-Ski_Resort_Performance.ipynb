# %% [markdown]
# # Advanced Ski Resort Analytics
#
# You work as the **lead data analyst** for **AlpineTrack**, managing data operations for a network of three ski resorts in the French Alps: Mont Blanc Station, Chamonix Valley, and Les Trois Vallées.
#
# <img src ="https://data-analytics-fullstack-assets.s3.eu-west-3.amazonaws.com/M05-Exploratory_Data_Analysis/M03-D04-AlpineTrackLogo.png"/>
#
# The executive team prepares for the annual board meeting. They need statistical evidence to support strategic decisions about pricing, capacity expansion, staff allocation, and marketing spend. Your raw operational data sits in CSV files, but executives demand professional visualizations that reveal patterns, correlations, and outliers.
#
# You will build a comprehensive analytical dashboard using Seaborn to transform operational metrics into actionable business intelligence.
#
# **Important:** All visualizations must use the AlpineTrack corporate color palette to maintain brand consistency across all reports.

# %% [markdown]
# ## Setup: Configure environment and load data
#
# Import libraries and configure visualization defaults. Seaborn requires both Matplotlib and Pandas to function properly. The operational data comes from the resort management system.
#
# **Brand Colors:**
# - Corporate Navy: `#3D4A5C`
# - Corporate Cream: `#E8E5D5`
# - Corporate Ice: `#A8C5DD`
# - Corporate Snow: `#F5F5F0`

# %%
# Import seaborn, matplotlib.pyplot, pandas, numpy, and warnings

# Filter warnings

# Define corporate brand colors
# corporate_navy = '#3D4A5C'
# corporate_cream = '#E8E5D5'
# corporate_ice = '#A8C5DD'
# corporate_snow = '#F5F5F0'
# corporate_palette = [corporate_navy, corporate_ice, corporate_cream]

# Apply Seaborn styling with whitegrid

# Set figure dpi to 300

# Set default figure size to (12, 6)

# Set random seed to 42

# Generate date range from 2024-12-01 for 120 days

# Create list of resort names: 'Mont Blanc Station', 'Chamonix Valley', 'Les Trois Vallées'

# Set n_days to 120

# Create empty dictionary with keys: 'date', 'resort', 'visitors', 'temperature', 'snowfall', 'lift_revenue', 'rental_revenue', 'wait_time', 'satisfaction'

# Fill 'date' with dates repeated 3 times (np.tile)

# Fill 'resort' with each resort name repeated 120 times (np.repeat)

# Loop through each resort:
    # Set base visitor count: Mont Blanc=1200, Chamonix=900, Les Trois Vallées=1500
    
    # Generate visitors: random integers between base-200 and base+300 for 120 days
    # Add 400 to days 20-29 for holiday boost
    
    # Generate temperature: normal distribution with mean=-3, std=4, size=120
    
    # Generate snowfall: uniform distribution between 0 and 35, size=120
    
    # Calculate lift_revenue: visitors * uniform(45, 55)
    
    # Calculate rental_revenue: visitors * uniform(12, 18)
    
    # Calculate wait_time: 3 + (visitors / base) * uniform(3, 5)
    
    # Calculate satisfaction: 8 - (wait_time / 10) + (snowfall / 20) + normal(0, 0.5)
    # Clip satisfaction between 1 and 10
    
    # Extend all lists in data dictionary

# Create DataFrame from data dictionary

# Add column 'total_revenue': sum of lift_revenue and rental_revenue

# Add column 'month': extract month name from date

# Add column 'weekday': extract day name from date

# Add column 'is_weekend': check if day of week >= 5

# Add column 'day_type': map is_weekend to 'Weekend' or 'Weekday'

# Print first 10 rows

# Print dataset shape and column names

# %% [markdown]
# The dataset simulates realistic operational patterns. Each resort shows different visitor volumes reflecting actual capacity differences. Holiday periods spike across all locations. Revenue correlates with attendance but includes variation from pricing and package deals.

# %% [markdown]
# ## Task 1: Explore visitor patterns with relational plots
#
# Management asks whether visitor counts relate to snowfall and temperature. They want evidence to support weather-based marketing campaigns.
#
# Create a scatter plot showing visitors versus snowfall, with point colors representing temperature and point sizes representing total revenue. Use the `hue` parameter for temperature and `size` parameter for revenue.
#
# <Note type ="hint">
#
# Use `sns.scatterplot()` with multiple aesthetic mappings. For temperature coloring, use a diverging palette like 'coolwarm' since temperature has a meaningful midpoint around 0°C. Add transparency with `alpha=0.6` to reveal overlapping points. Use the `style` parameter to distinguish resorts with different marker shapes.
# </Note>

# %%
# Create figure with size (14, 7)

# Create scatter plot:
    # x='snowfall'
    # y='visitors'
    # hue='temperature'
    # size='total_revenue'
    # style='resort'
    # palette='coolwarm'
    # sizes=(50, 400)
    # alpha=0.6
    # edgecolor='black'
    # linewidth=0.5

# Add title: 'Visitor Attendance vs Snowfall (colored by temperature, sized by revenue)' with fontsize 16 and bold

# Add xlabel: 'Fresh Snowfall (cm)' with fontsize 13

# Add ylabel: 'Daily Visitors' with fontsize 13

# Position legend outside plot area at (1.05, 1), upper left, fontsize 9

# Add grid with alpha 0.3

# Apply tight_layout

# Show plot

# %% [markdown]
# The visualization reveals that heavy snowfall drives attendance regardless of temperature. Cold days with fresh snow generate maximum visits. Larger points cluster in high-snowfall regions, confirming that optimal conditions produce peak revenue. Different marker styles distinguish resorts, showing Les Trois Vallées consistently attracts more visitors.

# %% [markdown]
# ## Task 2: Analyze revenue distributions across resorts
#
# Finance wants to understand revenue variability. They need to see not just averages but the full distribution including outliers and skewness.
#
# Create violin plots comparing total revenue distributions across the three resorts, split by weekday versus weekend.
#
# <Note type ="hint">
#
# Use `sns.violinplot()` with `split=True` to show weekday/weekend on each violin. The `day_type` column already exists in the dataset. Use the corporate navy and ice colors for the two day types. Set `inner='quartile'` to show statistical markers inside the violins.
#
# </Note>

# %%
# Create figure with size (14, 7)

# Create violin plot:
    # x='resort'
    # y='total_revenue'
    # hue='day_type'
    # split=True
    # palette using [corporate_navy, corporate_ice]
    # inner='quartile'

# Add title: 'Revenue Distribution by Resort and Day Type' with fontsize 16 and bold

# Add xlabel: 'Resort' with fontsize 13

# Add ylabel: 'Total Daily Revenue ($)' with fontsize 13

# Configure legend with title 'Day Type' and fontsize 11

# Rotate x-axis labels 15 degrees

# Add grid on y-axis only with alpha 0.3

# Apply tight_layout

# Show plot

# %% [markdown]
# The split violins immediately show that weekends generate higher revenue across all resorts. Les Trois Vallées shows the widest weekend distribution, indicating high variability in peak-day performance. Mont Blanc Station maintains more consistent revenue. The quartile lines inside each violin reveal median positions and spread.

# %% [markdown]
# ## Task 3: Investigate wait time patterns with distribution analysis
#
# Operations claims wait times vary significantly by time of season. They want data proving which periods create bottlenecks.
#
# Create a joint plot examining the relationship between visitors and wait times, with marginal distributions showing each variable's spread.
#
# <Note type ="hint">
#
# Use `sns.jointplot()` with colored points by resort using the corporate palette. The marginal plots will automatically show distributions for each axis.
# </Note>

# %%
# Create joint plot:
    # x='visitors'
    # y='wait_time'
    # hue='resort'
    # kind='scatter'
    # height=10
    # alpha=0.5
    # palette=corporate_palette

# Add super title: 'Visitor Count vs Lift Wait Times' with fontsize 16, bold, y=1.02

# Apply tight_layout

# Show plot

# %% [markdown]
# The central scatter plot with marginal histograms reveals positive correlation between attendance and wait times. The marginal distributions show visitors cluster around each resort's typical capacity while wait times spread more widely. High-attendance days create disproportionately long waits, suggesting capacity constraints during peak periods.

# %% [markdown]
# ## Task 4: Compare multiple variables with pair plot
#
# The analytics team needs a comprehensive view of how operational metrics relate to each other. They want to identify which variables correlate strongly and which relationships merit deeper investigation.
#
# Create a pair plot examining relationships between visitors, snowfall, temperature, total revenue, wait time, and satisfaction. Color code by resort.
#
# <Note type ="hint">
#
# Select only the numerical columns of interest plus 'resort' before calling `sns.pairplot()`. Use `hue='resort'` with the corporate palette to distinguish resorts. Set `diag_kind='kde'` for smooth distribution curves on the diagonal. Configure `plot_kws` with `alpha=0.5` and `s=30` for readability. Set `height=2.5` for appropriately sized subplots.
#
# </Note>

# %%
# Create list of variables: 'visitors', 'snowfall', 'temperature', 'total_revenue', 'wait_time', 'satisfaction'

# Select these columns plus 'resort' from resort_data

# Create pair plot:
    # hue='resort'
    # palette=corporate_palette
    # diag_kind='kde'
    # plot_kws with alpha=0.5 and s=30
    # height=2.5

# Add super title: 'Comprehensive Operational Metrics Analysis' with fontsize 16, bold, y=1.01

# Apply tight_layout

# Show plot

# %% [markdown]
# The grid reveals multiple insights simultaneously. Revenue correlates strongly with visitors. Satisfaction shows weak negative correlation with wait times. Snowfall relates moderately to visitor counts. Temperature shows little direct impact on revenue. The diagonal KDE plots confirm Les Trois Vallées operates at higher visitor volumes. This single visualization replaces dozens of individual analyses.

# %% [markdown]
# ## Task 5: Examine seasonal trends with line plots
#
# Marketing wants to understand how visitor patterns evolve across the season. They need evidence showing whether attendance grows, stabilizes, or declines from December through March.
#
# Create a line plot showing average daily visitors by month for each resort, with confidence intervals.
#
#
# <Note type ="hint">
#
# Use `sns.lineplot()` which automatically computes means and confidence intervals when multiple observations exist per x-value. Set `x='month'`, `y='visitors'`, and `hue='resort'` with the corporate palette. Add markers with `marker='o'` and `markersize=8`. Set `linewidth=2.5` and `ci=95` for 95% confidence intervals.
#
# </Note>

# %%
# Create figure with size (14, 7)

# Create line plot:
    # x='month'
    # y='visitors'
    # hue='resort'
    # marker='o'
    # markersize=8
    # linewidth=2.5
    # palette=corporate_palette
    # ci=95

# Add title: 'Average Daily Visitors by Month and Resort' with fontsize 16 and bold

# Add xlabel: 'Month' with fontsize 13

# Add ylabel: 'Average Daily Visitors' with fontsize 13

# Configure legend with title 'Resort', fontsize 11, title_fontsize 12

# Add grid with alpha 0.3

# Apply tight_layout

# Show plot

# %% [markdown]
# The lines show December starts slow, January peaks as holiday travelers arrive, and February maintains high volume before March declines. Confidence bands reveal uncertainty levels. Les Trois Vallées maintains the highest attendance throughout. This pattern helps staff planning and inventory management for peak months.

# %% [markdown]
# ## Task 6: Analyze categorical patterns with strip and swarm plots
#
# Customer service wants to know if satisfaction varies by day of week. They suspect weekend crowds lower satisfaction despite higher revenue.
#
# Create a swarm plot showing satisfaction scores across weekdays, overlaid on a box plot for context.
#
# <Note type ="hint">
#
# Use `sns.boxplot()` first with `color='lightgray'` and `width=0.5`, then overlay `sns.swarmplot()` on the same axes. The swarm plot should use `hue='resort'` with the corporate palette. Set `size=3` and `alpha=0.6` for the swarm to prevent overcrowding. Position the legend outside the plot area.
#
# </Note>

# %%
# Create figure with size (14, 7)

# Create box plot base layer:
    # x='weekday'
    # y='satisfaction'
    # color='lightgray'
    # width=0.5

# Overlay swarm plot:
    # x='weekday'
    # y='satisfaction'
    # hue='resort'
    # palette=corporate_palette
    # size=3
    # alpha=0.6

# Add title: 'Customer Satisfaction Distribution by Day of Week' with fontsize 16 and bold

# Add xlabel: 'Day of Week' with fontsize 13

# Add ylabel: 'Satisfaction Score (1-10)' with fontsize 13

# Position legend with title 'Resort' at (1.05, 1), upper left

# Add grid on y-axis only with alpha 0.3

# Apply tight_layout

# Show plot

# %% [markdown]
# The swarm plot reveals that satisfaction spreads widely on weekends despite box plot medians appearing similar. Individual points show how resort performance varies. Some weekend days achieve high satisfaction while others drop significantly. The pattern suggests that capacity management, not inherent day-of-week effects, drives satisfaction variability.

# %% [markdown]
# ## Task 7: Build distribution comparison with KDE and rug plots
#
# Operations wants to compare temperature distributions across resorts to understand microclimate differences that affect snowmaking needs.
#
# Create overlapping KDE plots for temperature by resort, with rug plots showing actual observation positions.
#
# <Note type ="hint">
#
# Use `sns.kdeplot()` with `fill=True`, `alpha=0.3`, and `linewidth=2.5`. Use the corporate palette for resort colors. Add rug plots manually using `plt.plot()` with vertical line markers '|' for each resort. Create a color mapping dictionary using corporate_navy, corporate_ice, and corporate_cream for the three resorts. The rug ticks reveal data clustering patterns. Add a vertical reference line at 0°C using `plt.axvline` in red with dashed style.
#
# </Note>

# %%
# Create figure with size (14, 7)

# Create KDE plot:
    # x='temperature'
    # hue='resort'
    # fill=True
    # alpha=0.3
    # linewidth=2.5
    # palette=corporate_palette

# Create color mapping dictionary for each resort using corporate colors

# Loop through each resort:
    # Filter data for current resort
    # Get temperature values
    # Plot rug using plt.plot with '|' marker, markersize=10, alpha=0.4, and resort color

# Add title: 'Temperature Distribution Comparison Across Resorts' with fontsize 16 and bold

# Add xlabel: 'Daily High Temperature (°C)' with fontsize 13

# Add ylabel: 'Density' with fontsize 13

# Configure legend with title 'Resort' and fontsize 11

# Add grid on y-axis only with alpha 0.3

# Add vertical line at x=0 with red color, dashed style, linewidth 1.5, alpha 0.7

# Apply tight_layout

# Show plot

# %% [markdown]
# The overlapping KDE curves show temperature distributions center around -3°C for all resorts with slight variations. Mont Blanc Station skews colder. Rug marks at the bottom confirm observation density, revealing that most days cluster near the mean. The red vertical line at 0°C highlights the freezing point, showing how often natural snowmaking occurs.

# %% [markdown]
# ## Task 8: Create multi-facet grid for comprehensive segmentation
#
# The executive team needs segmented analysis showing how revenue patterns vary by both resort and month. They want to see if seasonal effects impact resorts differently.
#
# Create a facet grid with separate histograms for each resort-month combination showing total revenue distributions.
#
# <Note type ="hint">
#
# Use `sns.FacetGrid()` with `col='month'` and `row='resort'`. Set `margin_titles=True`, `height=3`, and `aspect=1.2`. Map `sns.histplot` to each subplot using corporate navy color. Include KDE curves with `kde=True` and set `bins=15`. Add axis labels and titles using grid methods.
#
# </Note>

# %%
# Create FacetGrid:
    # col='month'
    # row='resort'
    # margin_titles=True
    # height=3
    # aspect=1.2

# Map sns.histplot to 'total_revenue' with kde=True, bins=15, color=corporate_navy

# Set axis labels: x='Total Revenue ($)', y='Frequency'

# Set titles using col_template and row_template

# Add super title: 'Revenue Distributions: Resort × Month Segmentation' with fontsize 16, bold, y=1.01

# Apply tight_layout

# Show plot

# %% [markdown]
# The grid reveals how revenue distributions shift across months and resorts. January shows tighter, higher-value distributions reflecting consistent peak performance. March spreads more widely with lower medians as season winds down. Les Trois Vallées maintains higher revenue floors across all months. This segmented view helps forecasting and budget planning for each location.

# %% [markdown]
# ## Task 9: Build executive dashboard with custom styling
#
# The board meeting requires a single-page dashboard presenting five key metrics with professional styling matching corporate branding.
#
# Create a comprehensive dashboard with: (1) visitor trend by resort, (2) revenue vs satisfaction scatter, (3) wait time distribution, (4) snowfall impact on visitors, and (5) satisfaction by resort box plot. Apply custom colors and styling.
#
# <Note type ="hint">
#
# Use `plt.figure()` with `add_gridspec()` for flexible layout control with 3 rows and 3 columns. Create subplots using `fig.add_subplot()` with different grid positions. Panel 1 spans columns 0-2 of row 0. Panel 2 is row 0, column 2. Panel 3 spans columns 0-2 of row 1. Panel 4 is row 1, column 2. Panel 5 spans all columns of row 2. Use only corporate brand colors throughout (corporate_navy, corporate_ice, corporate_cream for resorts; corporate_navy and corporate_ice for day types). Add reference lines and annotations. Set background color to corporate_snow for all axes.
#
# </Note>

# %%
# Create figure with size (18, 14)

# Create grid spec with 3 rows, 3 columns, hspace=0.4, wspace=0.4

# Add super title: 'AlpineTrack Executive Performance Dashboard - Winter 2024' with fontsize 20, bold, y=0.98

# Panel 1: Visitor trends (top row, spans first 2 columns)
    # Add subplot at gs[0, :2]
    # Create line plot: x='date', y='visitors', hue='resort', palette=corporate_palette, linewidth=2.5
    # Set title: 'Daily Visitor Trends by Resort' with fontsize 14, bold, pad=10
    # Set xlabel: 'Date', fontsize 11
    # Set ylabel: 'Visitors', fontsize 11
    # Configure legend with title 'Resort', fontsize 9, title_fontsize 10
    # Add grid with alpha 0.3

# Panel 2: Revenue vs Satisfaction (top row, column 2)
    # Add subplot at gs[0, 2]
    # Create scatter plot: x='total_revenue', y='satisfaction', hue='resort', palette=corporate_palette, alpha=0.5, s=50
    # Set title: 'Revenue vs Satisfaction' with fontsize 14, bold, pad=10
    # Set xlabel: 'Revenue ($)', fontsize 11
    # Set ylabel: 'Satisfaction', fontsize 11
    # Configure legend with title 'Resort', fontsize 8
    # Add grid with alpha 0.3

# Panel 3: Wait time distributions (middle row, spans first 2 columns)
    # Add subplot at gs[1, :2]
    # Create violin plot: x='resort', y='wait_time', palette=corporate_palette, inner='quartile'
    # Set title: 'Lift Wait Time Distribution by Resort' with fontsize 14, bold, pad=10
    # Set xlabel: 'Resort', fontsize 11
    # Set ylabel: 'Average Wait (min)', fontsize 11
    # Rotate x-tick labels 15 degrees
    # Add horizontal line at y=7 with red color, dashed style, linewidth 1.5, alpha 0.6
    # Add text annotation: 'Target: 7 min' at position (2.5, 7.3), fontsize 9, red color
    # Add grid on y-axis with alpha 0.3

# Panel 4: Snowfall impact (middle row, column 2)
    # Add subplot at gs[1, 2]
    # Loop through resorts with index:
        # Filter data for current resort
        # Create regression plot: x='snowfall', y='visitors', scatter_kws with alpha=0.3 and s=30, line_kws with linewidth=2, color from corporate_palette, label=resort
    # Set title: 'Snowfall Impact on Attendance' with fontsize 14, bold, pad=10
    # Set xlabel: 'Snowfall (cm)', fontsize 11
    # Set ylabel: 'Visitors', fontsize 11
    # Add legend with fontsize 8
    # Add grid with alpha 0.3

# Panel 5: Satisfaction by resort (bottom row, spans all columns)
    # Add subplot at gs[2, :]
    # Create box plot: x='resort', y='satisfaction', hue='day_type', palette using [corporate_navy, corporate_ice]
    # Set title: 'Customer Satisfaction: Resort × Day Type Analysis' with fontsize 14, bold, pad=10
    # Set xlabel: 'Resort', fontsize 11
    # Set ylabel: 'Satisfaction Score', fontsize 11
    # Rotate x-tick labels 15 degrees
    # Configure legend with title 'Day Type', fontsize 10, title_fontsize 10
    # Add horizontal line at y=7.5 with green color, dashed style, linewidth 1.5, alpha 0.6
    # Add text annotation: 'Excellence Threshold: 7.5' at position (2.5, 7.7), fontsize 9, green color
    # Add grid on y-axis with alpha 0.3

# Set background color to corporate_snow for all 5 axes

# Apply tight_layout

# Save figure as 'alpine_executive_dashboard.png' with dpi=300, bbox_inches='tight'

# Show plot

# %% [markdown]
# The executive dashboard presents five critical metrics in coordinated panels. Visitor trends show seasonal patterns and resort comparisons. Revenue-satisfaction scatter identifies whether high-revenue days sacrifice experience. Wait time distributions reveal operational efficiency. Snowfall regression proves weather impact. Satisfaction analysis segments by day type. Corporate colors and reference lines guide interpretation. The single-page layout enables quick executive decision-making during board presentations.
