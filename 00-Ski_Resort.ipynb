# %% [markdown]
# # Ski Resort Analytics
#
# You work as a data analyst for **AlpineTrack**, a company that manages lift operations and guest services across three ski resorts in the French Alps. The operations team needs visual reports to optimize staffing, pricing, and maintenance schedules.
#
# <img src ="https://data-analytics-fullstack-assets.s3.eu-west-3.amazonaws.com/M05-Exploratory_Data_Analysis/M03-D04-AlpineTrackLogo.png"/>
#
# Your manager wants dashboards that show visitor patterns, lift usage, weather impact, and revenue performance. The board reviews these reports monthly to make strategic decisions about expansion and resource allocation.
#
# You will use **Matplotlib** to transform raw operational data into clear visualizations that drive action.

# %% [markdown]
# ## Setup: Import and configure
#
# Start by importing the libraries you need. Set default figure sizes so all plots maintain consistent dimensions across your reports.

# %%
# Import matplotlib.pyplot, numpy, and pandas

# Set the default figure size to (10, 6) using plt.rcParams

# %% [markdown]
# This configuration prepares your environment. The default figure size ensures your plots fit well in reports without manual adjustment each time.

# %% [markdown]
# ## Task 1: Track daily visitors across the season
#
# The resort logged visitor counts for each day of the ski season. Management wants to see how attendance changed from December through March to identify peak periods and plan staffing.
#
# Create a line plot showing daily visitor numbers across the season. Use the December to March timeframe with realistic fluctuations.
#
# <Note type = "hint">
# Generate a sequence of daily dates for the ski season, starting December 1, 2024, for 120 days using pd.date_range. Set a random seed for reproducibility of 42.
#
# Simulate a base number of daily visitors between 800 and 1500 for the 120-day ski season.
#
# Simulate a spike in visitors during the Christmas holidays by adding 600 more visitors per day for days 20 to 29.
# Simulate another spike during the February vacation by adding 500 more visitors per day for days 70 to 76.
# </Note>

# %%
# Generate 120 daily dates starting from December 1, 2024

# Set random seed to 42

# Create base visitor numbers between 800 and 1500 for 120 days

# Add 600 visitors to days 20-29 for Christmas spike

# Add 500 visitors to days 70-76 for February vacation spike

# Create line plot with dates on x-axis and visitor counts on y-axis

# Add title: 'Daily Visitor Count - Winter Season 2024' with fontsize 16 and bold

# Add xlabel 'Date' with fontsize 12

# Add ylabel 'Number of Visitors' with fontsize 12

# Rotate x-axis labels 45 degrees

# Add grid with alpha 0.3

# Apply tight_layout

# Show the plot

# %% [markdown]
# The line plot reveals clear spikes during holiday periods when families visit. Mid-week attendance drops consistently. This pattern helps schedule lift operators and rental staff efficiently.

# %% [markdown]
# ## Task 2: Compare lift usage across the resort
#
# The resort operates five main lifts. Operations wants to know which lifts carry the most passengers to prioritize maintenance and upgrades.
#
# Create a horizontal bar chart showing total passengers carried by each lift during the season.

# %%
# Create list of lift names: 'Summit Express', 'Alpine Quad', 'Glacier Lift', 'Beginner Tow', 'Valley Chair'

# Create list of passenger counts: 145000, 128000, 95000, 78000, 112000

# Define colors list with 5 custom colors

# Create horizontal bar chart using plt.barh

# Add title 'Total Passengers by Lift - Season 2024' with fontsize 16 and bold

# Add xlabel 'Total Passengers' with fontsize 12

# Add ylabel 'Lift Name' with fontsize 12

# Apply tight_layout

# Show the plot

# %% [markdown]
# Summit Express carried the most passengers because it accesses advanced terrain. The beginner tow shows lower usage, suggesting the resort attracts primarily intermediate and advanced skiers. This data justifies investing in Summit Express upgrades.

# %% [markdown]
# ## Task 3: Break down revenue sources
#
# The finance team wants to understand what drives resort income. Revenue comes from lift tickets, equipment rentals, ski school, food services, and retail.
#
# Create a pie chart showing the proportion of revenue from each source.
#
# <Note type = "hint">
#
# Use the explode parameter to pull out one slice slightly for emphasis. The first value in the explode tuple should be 0.1 and the rest should be 0. Add shadow=True for visual depth.
# </Note>

# %%
# Create list of revenue sources: 'Lift Tickets', 'Equipment Rental', 'Ski School', 'Food & Beverage', 'Retail'

# Create list of revenue amounts: 2800000, 950000, 720000, 1100000, 580000

# Define 5 custom colors

# Create explode tuple with first value 0.1 and rest 0

# Create pie chart with labels, autopct='%1.1f%%', startangle=90, colors, explode, and shadow=True

# Add title 'Revenue Distribution by Source - Season 2024' with fontsize 16 and bold

# Apply tight_layout

# Show the plot

# %% [markdown]
# Lift tickets generate 44% of total revenue, making them the core business. Food and beverage contributes significantly at 17%, suggesting the resort should invest in dining facilities. Retail shows the smallest share, indicating potential growth opportunity or intentional focus on core operations.

# %% [markdown]
# ## Task 4: Analyze temperature distribution
#
# Weather directly impacts resort operations. The team tracked daily high temperatures throughout the season to understand typical conditions and plan snowmaking operations.
#
# Create a histogram showing the distribution of daily high temperatures.
#
# <Note type = "hint">
#
# Use np.random.normal with loc=-2, scale=5, and size=120 to simulate temperature data. Calculate the mean temperature and add it as a vertical line using plt.axvline with a dashed style and a label showing the mean value.
#
# </Note>

# %%
# Set random seed to 42

# Generate 120 temperature values using normal distribution (mean=-2, std=5)

# Create figure with size (10, 6)

# Create histogram with 25 bins, custom color, alpha 0.7, and black edgecolor

# Calculate mean temperature

# Add vertical line at mean using plt.axvline with dashed style, red color, linewidth 2, and label

# Add title 'Daily High Temperature Distribution - Winter Season' with fontsize 16 and bold

# Add xlabel 'Temperature (°C)' with fontsize 12

# Add ylabel 'Number of Days' with fontsize 12

# Add legend

# Add grid with alpha 0.3 on y-axis only

# Apply tight_layout

# Show the plot

# %% [markdown]
# Most days cluster around -2°C, ideal for maintaining snow quality. The distribution shows some warmer days above 5°C that required increased snowmaking. Understanding this pattern helps budget for snowmaking energy costs and schedule maintenance during warmer periods.

# %% [markdown]
# ## Task 5: Compare lift wait times
#
# Guest satisfaction depends heavily on lift wait times. The resort monitors average wait times at each lift during peak hours to identify bottlenecks.
#
# Create a boxplot comparing wait time distributions across all five lifts.
#
# <Note type = "hint">
#
# Generate 100 samples for each lift using np.random.normal with different mean and standard deviation values. Use patch_artist=True in plt.boxplot to enable colored boxes. Customize boxprops, medianprops, whiskerprops, and capprops for professional styling.
#
# </Note>

# %%
# Generate 100 wait time samples for Summit Express (mean=8, std=2)

# Generate 100 wait time samples for Alpine Quad (mean=6, std=1.5)

# Generate 100 wait time samples for Glacier Lift (mean=5, std=1.8)

# Generate 100 wait time samples for Beginner Tow (mean=3, std=1)

# Generate 100 wait time samples for Valley Chair (mean=7, std=2.2)

# Combine all wait times into a list

# Create lift labels with line breaks: 'Summit\nExpress', 'Alpine\nQuad', etc.

# Create figure with size (12, 6)

# Create boxplot with tick_labels, patch_artist=True, and custom styling for boxprops, medianprops, whiskerprops, and capprops

# Add title 'Lift Wait Time Distribution (Peak Hours)' with fontsize 16 and bold

# Add ylabel 'Wait Time (minutes)' with fontsize 12

# Add xlabel 'Lift' with fontsize 12

# Add grid with alpha 0.3 on y-axis only

# Apply tight_layout

# Show the plot

# %% [markdown]
# Summit Express shows the longest median wait time at 8 minutes, confirming capacity issues. The beginner tow maintains short waits, indicating adequate capacity for new skiers. Several outliers appear across lifts, representing occasional delays. This analysis supports the decision to upgrade Summit Express capacity.

# %% [markdown]
# ## Task 6: Examine snowfall versus visitors
#
# Marketing claims that fresh snowfall drives attendance. Operations wants proof to justify weather-based advertising campaigns.
#
# Create a scatter plot showing the relationship between overnight snowfall and next-day visitor counts.
#
# <Note type = "hint">
#
# Use np.random.uniform to generate snowfall values between 0 and 40 cm. Calculate visitors as 1000 plus 25 times snowfall plus some random noise. Use np.polyfit with degree 1 to fit a linear regression line, then create a polynomial function with np.poly1d and plot it as a dashed line.
#
# </Note>

# %%
# Generate 60 snowfall values between 0 and 40 cm

# Calculate visitors: 1000 + snowfall * 25 + random noise (mean=0, std=200)

# Create figure with size (10, 6)

# Create scatter plot with alpha 0.6, marker size 80, blue color, and black edge

# Fit linear regression using np.polyfit with degree 1

# Create polynomial function using np.poly1d

# Plot trend line as dashed red line with linewidth 2 and equation label

# Add title 'Fresh Snowfall Impact on Visitor Attendance' with fontsize 16 and bold

# Add xlabel 'Overnight Snowfall (cm)' with fontsize 12

# Add ylabel 'Next-Day Visitors' with fontsize 12

# Add legend

# Add grid with alpha 0.3

# Apply tight_layout

# Show the plot

# %% [markdown]
# The positive correlation confirms that fresh snowfall increases attendance. Each centimeter of snow brings approximately 25 additional visitors. The trend line helps forecast attendance based on weather predictions. This evidence justifies spending on social media campaigns when heavy snow arrives.

# %% [markdown]
# ## Task 7: Build an operations dashboard
#
# The general manager wants a single-page dashboard showing the four most critical metrics: daily visitors, lift usage, revenue breakdown, and temperature patterns.
#
# Create a 2x2 subplot layout containing line plot, bar chart, pie chart, and histogram.
#
# <Note type = "hint">
#
# Use plt.subplots with 2 rows and 2 columns to create the grid layout. Set figsize to (14, 10). Add a global title using fig.suptitle. Access each subplot using axes[row, column] indexing. Remember to use plt.tight_layout with rect parameter to prevent title overlap.
#
# </Note>

# %%
# Generate all data from previous tasks (dates, visitors, lifts, passengers, revenue, temperatures)

# Create 2x2 subplot grid with figsize (14, 10)

# Add global title using fig.suptitle

# Plot 1 (top-left): Line chart of daily visitors

# Plot 2 (top-right): Horizontal bar chart of lift passengers

# Plot 3 (bottom-left): Pie chart of revenue sources

# Plot 4 (bottom-right): Histogram of temperature distribution with mean line

# Apply tight_layout with rect=[0, 0, 1, 0.96]

# Show the dashboard

# %% [markdown]
# The dashboard provides immediate insight into resort performance. Management sees visitor patterns, identifies the busiest lift, understands revenue drivers, and confirms weather conditions—all in one view. This layout supports quick decision-making in weekly operations meetings.

# %% [markdown]
# ## Task 8: Save the dashboard for presentation
#
# The general manager needs to include your dashboard in next week's board presentation. Save the visualization in multiple formats for different uses.
#
# Export the dashboard as high-resolution PNG for PowerPoint, PDF for printed handouts, and SVG for the annual report.
#
# <Note type = "hint">
#
# Use plt.savefig three times with different file extensions. Set dpi=300 for PNG to ensure high resolution. Use bbox_inches='tight' to prevent label clipping in all formats.
#
# </Note>

# %%
# Create the dashboard using code from Task 7

# Save as PNG with dpi=300 and bbox_inches='tight'

# Save as PDF with bbox_inches='tight'

# Save as SVG with bbox_inches='tight'

# %% [markdown]
# The PNG file works for inserting into PowerPoint slides. The PDF maintains quality when printed for board packets. The SVG format scales infinitely for the annual report. Check your working directory to confirm all three files saved successfully.

# %% [markdown]
# ## Task 9: Customize for brand guidelines
#
# Marketing requires all reports to match AlpineTrack's brand colors and fonts. Update the dashboard styling to use the corporate palette and professional formatting.
#
# Apply consistent styling across all subplots using corporate colors, bold titles, and enhanced grid lines.
#
# <Note type = "hint">
#
# Define brand colors at the start: corporate_navy, corporate_cream, corporate_ice, corporate_snow. Set figure background using fig.patch.set_facecolor. For each subplot, set facecolor using axes[row, col].set_facecolor. Remove top and right spines using set_visible(False). Add value labels to bar charts using text method. Customize all text elements with color and fontweight parameters.
#
# </Note>

# %%
# Define brand colors: corporate_navy '#3D4A5C', corporate_cream '#E8E5D5', corporate_ice '#A8C5DD', corporate_snow '#F5F5F0'

# Generate all data from previous tasks

# Create 2x2 subplot grid

# Set figure background color to corporate_snow

# Add global title with corporate_navy color

# Plot 1: Line chart with corporate_navy line, cream background, styled labels and grid

# Remove top and right spines

# Plot 2: Horizontal bar chart with alternating brand colors, value labels, cream background

# Remove top and right spines

# Plot 3: Pie chart with brand color palette, white percentage text, styled wedges

# Plot 4: Histogram with corporate_navy bars, ice-colored mean line, cream background, legend

# Remove top and right spines

# Apply tight_layout and save as 'branded_dashboard.png'

# Show the dashboard

# %% [markdown]
# The branded dashboard now matches corporate identity guidelines. The consistent color scheme creates visual cohesion. Bold titles and subtle grids improve readability without cluttering the display. This professional appearance makes the dashboard suitable for external stakeholder presentations and annual reports.
